# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as mlt
# %matplotlib inline
from plotly import __version__
print (__version__)
# Out:
# 4.5.1

# %%
import cufflinks as cs
from plotly.offline import download_plotlyjs,init_notebook_mode,plot,iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
cs.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df=pd.read_csv('top50.csv', encoding='latin-1')  # encoding='ISO-8859-1'

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
print(df.shape)
print(df.columns)

df.head()
# Out:
# (50, 14)
# Index(['Unnamed: 0', 'Track.Name', 'Artist.Name', 'Genre', 'Beats.Per.Minute',
#        'Energy', 'Danceability', 'Loudness..dB..', 'Liveness', 'Valence.',
#        'Length.', 'Acousticness..', 'Speechiness.', 'Popularity'],
#       dtype='object')
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# ...

# %% [markdown]
# #### display the detail of songs that have popularity more than 80

# %%
df[df['Popularity']>80]
# Out:
#     Unnamed: 0                                         Track.Name  \
# 1            2                                              China
# 2            3                      boyfriend (with Social House)
# 3            4                    Beautiful People (feat. Khalid)
# 4            5                        Goodbyes (Feat. Young Thug)
# 5            6                  I Don't Care (with Justin Bieber)
# 6            7                                             Ransom
# 7            8                                  How Do You Sleep?
# 8            9                              Old Town Road - Remix
# 9           10                                            bad guy
# 10          11                                           Callaita
# 11          12              Loco Contigo (feat. J. Balvin & Tyga)
# 12          13                                  Someone You Loved
# 13          14                                 Otro Trago - Remix
# ...

# %%
print(df[df.Popularity>80].shape)
# Out:
# (46, 14)

# %% [markdown]
# #### which is the maximun lenght, beats per min?

# %%
df.head(1)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name         Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes  canadian pop               117
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
#
#    Acousticness..  Speechiness.  Popularity
# 0               4             3          79

# %%
df[df['Length.']==df['Length.'].max()]
# Out:
#     Unnamed: 0            Track.Name  Artist.Name           Genre  \
# 22          23  No Me Conoce - Remix  Jhay Cortez  reggaeton flow
#
#     Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  \
# 22                92      79            81              -4         9
#
#     Valence.  Length.  Acousticness..  Speechiness.  Popularity
# 22        58      309              14             7          83

# %%
print('maximun length is',df['Length.'].max())
# Out:
# maximun length is 309

# %%
print('Maximun value for beats per min is',df['Beats.Per.Minute'].max())
# Out:
# Maximun value for beats per min is 190

# %% [markdown]
# #### which is the minimun lenght, beats per min?

# %%
print('maximun length is',df['Length.'].min())
# Out:
# maximun length is 115

# %%
print('Maximun value for beats per min is',df['Beats.Per.Minute'].min())
# Out:
# Maximun value for beats per min is 85

# %%
df[df['Length.']==df['Length.'].min()]
# Out:
#     Unnamed: 0 Track.Name Artist.Name        Genre  Beats.Per.Minute  Energy  \
# 21          22     Panini   Lil Nas X  country rap               154      59
#
#     Danceability  Loudness..dB..  Liveness  Valence.  Length.  Acousticness..  \
# 21            70              -6        12        48      115              34
#
#     Speechiness.  Popularity
# 21             8          91

# %% [markdown]
# #### Create a new col <Track.Name.lenght> and store the length

# %%
len('Señorita')
# Out:
# 8

# %%
df['Track.Name.lenght']= df['Track.Name'].apply(lambda x: len(x))

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %% [markdown]
# #### create a new column <Artist.Name.New> and store the first name in it

# %%
"Shawn Mendes".split(' ')[0]
# Out:
# 'Shawn'

# %%
df['Artist.Name.New']=df['Artist.Name'].apply(lambda x: x.split(' ')[0])

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %% [markdown]
# #### how many songs from "dance pop" genre

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df['Genre'].value_counts()
# Out:
# dance pop           8
# pop                 7
# latin               5
# canadian hip hop    3
# edm                 3
# dfw rap             2
# reggaeton           2
# canadian pop        2
# panamanian pop      2
# electropop          2
# country rap         2
# reggaeton flow      2
# brostep             2
# r&b en espanol      1
# big room            1
# australian pop      1
# escape room         1
# pop house           1
# atl hip hop         1
# boy band            1
# trap music          1
# Name: Genre, dtype: int64

# %%
df[df.Genre=='dance pop'].count()
# Out:
# Unnamed: 0           8
# Track.Name           8
# Artist.Name          8
# Genre                8
# Beats.Per.Minute     8
# Energy               8
# Danceability         8
# Loudness..dB..       8
# Liveness             8
# Valence.             8
# Length.              8
# Acousticness..       8
# Speechiness.         8
# Popularity           8
# Track.Name.lenght    8
# Artist.Name.New      8
# dtype: int64

# %%
print(df[df.Genre=='dance pop'].shape[0])
# Out:
# 8

# %% [markdown]
# #### Whta isthe avg Lenght. for each genre

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
# whenever question ask for "each", use "groupby"
df2 = df.groupby('Genre')['Length.'].mean()
# Out:
# Genre
# atl hip hop         200.000000
# australian pop      210.000000
# big room            164.000000
# boy band            181.000000
# brostep             198.000000
# canadian hip hop    193.000000
# canadian pop        191.000000
# country rap         136.000000
# dance pop           202.625000
# dfw rap             166.500000
# edm                 218.666667
# electropop          194.500000
# escape room         173.000000
# latin               225.200000
# panamanian pop      257.000000
# pop                 195.428571
# pop house           153.000000
# r&b en espanol      162.000000
# reggaeton           213.500000
# reggaeton flow      305.500000
# trap music          131.000000
# Name: Length., dtype: float64

# %% [markdown]
# #### find out the avg of the legth for each artist.

# %%
df.head(2)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name           Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes    canadian pop               117
# 1           2      China      Anuel AA  reggaeton flow               105
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
# 1      81            79              -4         8        61      302
#
#    Acousticness..  Speechiness.  Popularity  Track.Name.lenght Artist.Name.New
# 0               4             3          79                  8           Shawn
# 1               8             9          92                  5           Anuel

# %%
df.groupby('Artist.Name')['Length.'].mean()
# Out:
# Artist.Name
# Ali Gatie           213.0
# Anuel AA            302.0
# Ariana Grande       182.5
# Bad Bunny           251.0
# Billie Eilish       194.5
# Chris Brown         261.0
# DJ Snake            185.0
# Daddy Yankee        193.0
# Drake               205.0
# Ed Sheeran          196.5
# J Balvin            232.5
# Jhay Cortez         309.0
# Jonas Brothers      181.0
# Katy Perry          224.0
# Khalid              198.0
# Kygo                228.0
# Lady Gaga           216.0
# Lauv                199.0
# Lewis Capaldi       182.0
# Lil Nas X           136.0
# Lil Tecca           131.0
# Lizzo               173.0
# Lunay               266.0
# MEDUZA              153.0
# Maluma              176.0
# Marshmello          198.0
# Martin Garrix       164.0
# Nicky Jam           202.0
# Post Malone         166.5
# ROSALÍA             162.0
# Sam Smith           202.0
# Sech                257.0
# Shawn Mendes        191.0
# Taylor Swift        171.0
# The Chainsmokers    214.0
# ...

# %% [markdown]
# #### What si the max lenght of each Genre?

# %%
df.head(2)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name           Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes    canadian pop               117
# 1           2      China      Anuel AA  reggaeton flow               105
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
# 1      81            79              -4         8        61      302
#
#    Acousticness..  Speechiness.  Popularity  Track.Name.lenght Artist.Name.New
# 0               4             3          79                  8           Shawn
# 1               8             9          92                  5           Anuel

# %%
df.groupby('Genre')['Length.'].max()
# Out:
# Genre
# atl hip hop         200
# australian pop      210
# big room            164
# boy band            181
# brostep             214
# canadian hip hop    213
# canadian pop        191
# country rap         157
# dance pop           261
# dfw rap             175
# edm                 228
# electropop          195
# escape room         173
# latin               266
# panamanian pop      288
# pop                 220
# pop house           153
# r&b en espanol      162
# reggaeton           251
# reggaeton flow      309
# trap music          131
# Name: Length., dtype: int64

# %% [markdown]
# #### What is the max lenght of each Artist?

# %%
df.head(1)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name         Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes  canadian pop               117
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
#
#    Acousticness..  Speechiness.  Popularity  Track.Name.lenght Artist.Name.New
# 0               4             3          79                  8           Shawn

# %%
df.groupby('Artist.Name')['Length.'].max()
# Out:
# Artist.Name
# Ali Gatie           213
# Anuel AA            302
# Ariana Grande       186
# Bad Bunny           251
# Billie Eilish       195
# Chris Brown         261
# DJ Snake            185
# Daddy Yankee        193
# Drake               205
# Ed Sheeran          220
# J Balvin            243
# Jhay Cortez         309
# Jonas Brothers      181
# Katy Perry          224
# Khalid              198
# Kygo                228
# Lady Gaga           216
# Lauv                199
# Lewis Capaldi       182
# Lil Nas X           157
# Lil Tecca           131
# Lizzo               173
# Lunay               266
# MEDUZA              153
# Maluma              176
# Marshmello          214
# Martin Garrix       164
# Nicky Jam           202
# Post Malone         175
# ROSALÍA             162
# Sam Smith           202
# Sech                288
# Shawn Mendes        191
# Taylor Swift        171
# The Chainsmokers    218
# Tones and I         210
# Y2K                 161
# ...

# %% [markdown]
# #### How many songs share same popularity?

# %%
df.head()
# Out:
#    Unnamed: 0                       Track.Name    Artist.Name           Genre  \
# 0           1                         Señorita   Shawn Mendes    canadian pop
# 1           2                            China       Anuel AA  reggaeton flow
# 2           3    boyfriend (with Social House)  Ariana Grande       dance pop
# 3           4  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4           5      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
# ...

# %%
df.groupby('Popularity')['Track.Name'].count()
# Out:
# Popularity
# 70    1
# 78    1
# 79    1
# 80    1
# 82    2
# 83    2
# 84    3
# 85    1
# 86    2
# 87    4
# 88    8
# 89    8
# 90    3
# 91    7
# 92    3
# 93    1
# 94    1
# 95    1
# Name: Track.Name, dtype: int64

# %% [markdown]
# #### Rank each song based on popularity?

# %%
df.groupby('Popularity')['Track.Name'].transform(lambda x: x.rank())
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     3.0
# 7     1.0
# 8     2.0
# 9     1.0
# 10    1.0
# 11    2.0
# 12    7.0
# 13    3.0
# 14    2.0
# 15    2.0
# 16    2.0
# 17    6.0
# 18    5.0
# 19    7.0
# 20    4.0
# 21    3.0
# 22    2.0
# 23    5.0
# 24    8.0
# 25    1.0
# 26    1.0
# 27    3.0
# 28    1.0
# 29    5.0
# 30    2.0
# 31    2.0
# 32    1.0
# 33    7.0
# 34    4.0
# 35    6.0
# 36    2.0
# 37    1.0
# 38    1.0
# 39    1.0
# 40    4.0
# 41    3.0
# 42    4.0
# 43    3.0
# 44    2.0
# 45    6.0
# 46    8.0
# 47    3.0
# 48    1.0
# 49    1.0
# Name: Track.Name, dtype: float64

# %% [markdown]
# #### Rank each song based on Danceability?

# %%
df.head(1)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name         Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes  canadian pop               117
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
#
#    Acousticness..  Speechiness.  Popularity  Track.Name.lenght Artist.Name.New
# 0               4             3          79                  8           Shawn

# %%
df.groupby('Danceability')['Popularity'].transform(lambda x: x.rank())
# Out:
# 0     1.0
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     1.0
# 6     4.0
# 7     1.0
# 8     1.0
# 9     3.0
# 10    1.0
# 11    2.0
# 12    1.0
# 13    1.0
# 14    1.0
# 15    1.0
# 16    2.0
# 17    2.0
# 18    2.0
# 19    2.0
# 20    1.0
# 21    2.0
# 22    2.0
# 23    3.0
# 24    2.0
# 25    1.0
# 26    1.0
# 27    2.0
# 28    1.0
# 29    2.0
# 30    1.0
# 31    1.5
# 32    1.5
# 33    2.0
# 34    1.0
# 35    2.0
# 36    3.0
# 37    1.0
# 38    1.0
# 39    1.0
# 40    2.5
# 41    2.0
# 42    1.0
# 43    1.0
# 44    2.0
# 45    1.0
# 46    1.0
# 47    2.5
# 48    1.0
# 49    1.0
# Name: Popularity, dtype: float64

# %% [markdown]
# #### number of tracks per artists

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                         Track.Name    Artist.Name           Genre  \
# 0                         Señorita   Shawn Mendes    canadian pop
# 1                            China       Anuel AA  reggaeton flow
# 2    boyfriend (with Social House)  Ariana Grande       dance pop
# 3  Beautiful People (feat. Khalid)     Ed Sheeran             pop
# 4      Goodbyes (Feat. Young Thug)    Post Malone         dfw rap
#
#    Beats.Per.Minute  Energy  Danceability  Loudness..dB..  Liveness  Valence.  \
# 0               117      55            76              -6         8        75
# 1               105      81            79              -4         8        61
# 2               190      80            40              -4        16        70
# 3                93      65            64              -8         8        55
# 4               150      65            58              -4        11        18
#
#    Length.  Acousticness..  Speechiness.  Popularity
# ...

# %%
df['Artist.Name'].value_counts()
# Out:
# Ed Sheeran          4
# Shawn Mendes        2
# Ariana Grande       2
# J Balvin            2
# Sech                2
# Post Malone         2
# Lil Nas X           2
# The Chainsmokers    2
# Marshmello          2
# Billie Eilish       2
# Daddy Yankee        1
# Khalid              1
# MEDUZA              1
# Lizzo               1
# Lunay               1
# Lewis Capaldi       1
# Maluma              1
# Jhay Cortez         1
# Lil Tecca           1
# Lady Gaga           1
# Taylor Swift        1
# Jonas Brothers      1
# ROSALÍA             1
# Young Thug          1
# Bad Bunny           1
# Lauv                1
# Katy Perry          1
# Y2K                 1
# Ali Gatie           1
# Sam Smith           1
# Anuel AA            1
# Nicky Jam           1
# Kygo                1
# Drake               1
# Tones and I         1
# Chris Brown         1
# Martin Garrix       1
# DJ Snake            1
# Name: Artist.Name, dtype: int64

# %% [markdown]
# #### Avg, max min and std deviation of each column

# %%
df.describe()
# Out:
#        Unnamed: 0  Beats.Per.Minute     Energy  Danceability  Loudness..dB..  \
# count    50.00000         50.000000  50.000000      50.00000       50.000000
# mean     25.50000        120.060000  64.060000      71.38000       -5.660000
# std      14.57738         30.898392  14.231913      11.92988        2.056448
# min       1.00000         85.000000  32.000000      29.00000      -11.000000
# 25%      13.25000         96.000000  55.250000      67.00000       -6.750000
# 50%      25.50000        104.500000  66.500000      73.50000       -6.000000
# 75%      37.75000        137.500000  74.750000      79.75000       -4.000000
# max      50.00000        190.000000  88.000000      90.00000       -2.000000
#
#         Liveness   Valence.     Length.  Acousticness..  Speechiness.  \
# count  50.000000  50.000000   50.000000       50.000000     50.000000
# mean   14.660000  54.600000  200.960000       22.160000     12.480000
# ...

# %%
numerical_col = df.select_dtypes(include = 'number')

# %%
# def mean(series):
#     return np.mean(series)
numerical_col = df.select_dtypes(include = 'number').columns
df[numerical_col].apply(lambda x: np.mean(x))
df[numerical_col].apply(lambda x: np.min(x))
df[numerical_col].apply(lambda x: np.max(x))
df[numerical_col].apply(lambda x: np.std(x))
# Out:
# Unnamed: 0          14.430870
# Beats.Per.Minute    30.587847
# Energy              14.088875
# Danceability        11.809979
# Loudness..dB..       2.035780
# Liveness            11.006562
# Valence.            22.111535
# Length.             38.750463
# Acousticness..      18.804638
# Speechiness.        11.049416
# Popularity           4.446347
# dtype: float64

# %% [markdown]
# #### Avg, max min and std deviation of each row

# %%
numerical_col = df.select_dtypes(include = 'number').columns
df[numerical_col].apply(lambda x: np.mean(x), axis=1)
df[numerical_col].apply(lambda x: np.min(x), axis=1)
df[numerical_col].apply(lambda x: np.max(x), axis=1)
df[numerical_col].apply(lambda x: np.std(x), axis=1)
# Out:
# 0     58.703908
# 1     83.806448
# 2     64.462559
# 3     56.368621
# 4     57.770850
# 5     63.574515
# 6     57.278355
# 7     59.005953
# 8     53.493029
# 9     57.563906
# 10    73.608637
# 11    52.887531
# 12    53.158892
# 13    84.096757
# 14    60.462269
# 15    71.944997
# 16    73.157139
# 17    47.419353
# 18    51.870149
# 19    57.607535
# 20    51.223703
# 21    46.996747
# 22    83.447415
# 23    69.638619
# 24    56.959025
# 25    54.683915
# 26    56.090835
# 27    58.180682
# 28    55.491642
# 29    59.768285
# 30    58.387987
# 31    54.254984
# 32    48.731852
# 33    57.600935
# 34    60.981368
# 35    49.646852
# 36    67.882860
# 37    53.275054
# 38    57.224944
# 39    53.938441
# 40    64.268034
# 41    50.598403
# 42    58.222145
# 43    60.646926
# 44    46.501933
# 45    49.177533
# 46    64.087234
# 47    58.068071
# 48    58.155534
# 49    56.131339
# dtype: float64

# %% [markdown]
# #### Add	a	new	column	where	each	row	will	represent	difference	between	row	value	and	mean	of	the	each	genre	group.

# %%
# <length_variance>
df.head(1)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name         Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes  canadian pop               117
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
#
#    Acousticness..  Speechiness.  Popularity
# 0               4             3          79

# %%
df['length_variance'] = df.groupby('Genre')['Length.'].transform(lambda x: len(x))

# %%
df.head(2)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name           Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes    canadian pop               117
# 1           2      China      Anuel AA  reggaeton flow               105
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
# 1      81            79              -4         8        61      302
#
#    Acousticness..  Speechiness.  Popularity  length_variance
# 0               4             3          79                2
# 1               8             9          92                2

# %% [markdown]
# #### Take	log	transform	on	Loudness	DB	and	add	as	<log_loudness_db>	column

# %%
# <log_loudness_db>
df.head(2)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name           Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes    canadian pop               117
# 1           2      China      Anuel AA  reggaeton flow               105
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
# 1      81            79              -4         8        61      302
#
#    Acousticness..  Speechiness.  Popularity  length_variance
# 0               4             3          79                2
# 1               8             9          92                2

# %%
df['Loudness..dB']= np.log(np.abs(df['Loudness..dB..']))

# %%
df.head(2)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name           Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes    canadian pop               117
# 1           2      China      Anuel AA  reggaeton flow               105
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
# 1      81            79              -4         8        61      302
#
#    Acousticness..  Speechiness.  Popularity  length_variance  Loudness..dB
# 0               4             3          79                2      1.791759
# 1               8             9          92                2      1.386294

# %% [markdown]
# #### Visualize	if	there	is	linear	correlation	between	beats	per	minutes	and	popularity,	danceability	and	popularity,	energy	and	popularity

# %%
cols = ['Danceability', 'Popularity', 'Energy', 'Beats.Per.Minute']

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df[cols])

# %%
plt.scatter(df['Danceability'], df['Beats.Per.Minute'])

# %% [markdown]
# #### What	is	distribution	of	popularity	with	respect	to	energy

# %%
df.head(1)
# Out:
#    Unnamed: 0 Track.Name   Artist.Name         Genre  Beats.Per.Minute  \
# 0           1   Señorita  Shawn Mendes  canadian pop               117
#
#    Energy  Danceability  Loudness..dB..  Liveness  Valence.  Length.  \
# 0      55            76              -6         8        75      191
#
#    Acousticness..  Speechiness.  Popularity  length_variance  Loudness..dB
# 0               4             3          79                2      1.791759

# %%
col1 = ['Popularity', 'Energy']

# %%
sns.pairplot(df[col1])

# %%
plt.scatter(df['Popularity'], df['Energy'], alpha=.6)
plt.show()
